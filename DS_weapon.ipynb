# %%
import pandas as pd 
import numpy as nd 
DS3_weapon = pd.read_csv(r'E:\OneDrive\Рабочий стол\DS3_weapon.csv')#DS3_weapon = pd.read_csv("DS3_weapon.csv")
DS3_weapon
# Out:
#                        Name       Category Reinforcement         Damage  \
# 0                      Fist          Fists       Regular     20/0/0/0/0
# 1         Dragonhead Shield  Small Shields          Boss   116/0/12/0/0
# 2    Dragonhead Greatshield   Greatshields          Boss    145/0/0/0/0
# 3           White Birch Bow           Bows        Unique     82/0/0/0/0
# 4      Preacher's Right Arm         Staves        Unique    109/0/0/0/0
# ..                      ...            ...           ...            ...
# 282                Eleonora           Axes          Boss    156/0/0/0/0
# 283      Dragonslayer's Axe           Axes       Regular  105/0/0/105/0
# 284           Butcher Knife           Axes       Regular     95/0/0/0/0
# 285             Brigand Axe           Axes       Regular    124/0/0/0/0
# 286              Battle Axe           Axes       Regular    125/0/0/0/0
#
#     Damage Reduction Aux Effects Stat Requirements Stat Bonuses  Critical  \
# ...

# %% [markdown]
# Цель: показать на практике полученные на парах навыки работы с numpy и pandas. Был выведен весь датасет, в котором 390 строк и 17 стобцов о видах оружия их дамага и бонусов от статов .

# %%
DS3_weapon.to_numpy()
DS3_weapon.ndim
DS3_weapon.columns
# Out:
# Index(['Name', 'Category', 'Reinforcement', 'Damage', 'Damage Reduction',
#        'Aux Effects', 'Stat Requirements', 'Stat Bonuses', 'Critical',
#        'Weight', 'Stability', 'Durability', 'Sell Price', 'Spell Buff',
#        'Range', 'Buffable', 'Infusable'],
#       dtype='object')

# %% [markdown]
# Код, в котором идёт преобразование из датасета в массив numpy для использования функции, выводящей размерность массива.

# %%
DS3_weapon.nunique()
# Out:
# Name                 287
# Category              30
# Reinforcement          5
# Damage               146
# Damage Reduction     126
# Aux Effects           10
# Stat Requirements    193
# Stat Bonuses          67
# Critical               6
# Weight                48
# Stability             41
# Durability            40
# Sell Price            29
# Spell Buff            26
# Range                  7
# Buffable               2
# Infusable              2
# dtype: int64

# %% [markdown]
# Код для вывода всех колонок, которые обозначают имя оружия, категорию, рейндж, вес, критический урон, бонусы от статов, рекомендуемые статы и т.д.

# %%
DS3_weapon.sort_values(by="Category")
# Out:
#                    Name Category Reinforcement         Damage  \
# 286          Battle Axe     Axes       Regular    125/0/0/0/0
# 284       Butcher Knife     Axes       Regular     95/0/0/0/0
# 283  Dragonslayer's Axe     Axes       Regular  105/0/0/105/0
# 282            Eleonora     Axes          Boss    156/0/0/0/0
# 285         Brigand Axe     Axes       Regular    124/0/0/0/0
# ..                  ...      ...           ...            ...
# 22     Rose of Ariandel    Whips          Boss     79/0/0/0/0
# 272        Notched Whip    Whips       Regular     95/0/0/0/0
# 44         Spotted Whip    Whips       Regular    102/0/0/0/0
# 271                Whip    Whips       Regular     90/0/0/0/0
# 270       Witch's Locks    Whips        Unique    77/0/80/0/0
#
#     Damage Reduction Aux Effects Stat Requirements Stat Bonuses  Critical  \
# 286   45/30/25/25/30       0/0/0          12/8/0/0      D/D/-/-       100
# ...

# %% [markdown]
# Код для вывода кол-ва всех уникальных значений.

# %%
DS3_weapon.drop(columns="Damage")
# Out:
#                        Name       Category Reinforcement Damage Reduction  \
# 0                      Fist          Fists       Regular        0/0/0/0/0
# 1         Dragonhead Shield  Small Shields          Boss   70/65/90/35/55
# 2    Dragonhead Greatshield   Greatshields          Boss  100/55/90/30/55
# 3           White Birch Bow           Bows        Unique        -/-/-/-/-
# 4      Preacher's Right Arm         Staves        Unique   25/20/10/10/15
# ..                      ...            ...           ...              ...
# 282                Eleonora         Active          Boss   55/40/30/30/40
# 283      Dragonslayer's Axe         Active       Regular   45/30/25/25/30
# 284           Butcher Knife         Active       Regular   60/40/30/30/40
# 285             Brigand Axe         Active       Regular   45/30/25/25/30
# 286              Battle Axe         Active       Regular   45/30/25/25/30
#
#     Aux Effects Stat Requirements Stat Bonuses  Critical  Weight Stability  \
# ...

# %% [markdown]
# Код для сортировки всех строк по урону (не категориям) оружия.

# %%
DS3_weapon = DS3_weapon.replace({"Category":"Axes"}, "Active")
DS3_weapon
# Out:
#                        Name       Category Reinforcement         Damage  \
# 0                      Fist          Fists       Regular     20/0/0/0/0
# 1         Dragonhead Shield  Small Shields          Boss   116/0/12/0/0
# 2    Dragonhead Greatshield   Greatshields          Boss    145/0/0/0/0
# 3           White Birch Bow           Bows        Unique     82/0/0/0/0
# 4      Preacher's Right Arm         Staves        Unique    109/0/0/0/0
# ..                      ...            ...           ...            ...
# 282                Eleonora         Active          Boss    156/0/0/0/0
# 283      Dragonslayer's Axe         Active       Regular  105/0/0/105/0
# 284           Butcher Knife         Active       Regular     95/0/0/0/0
# 285             Brigand Axe         Active       Regular    124/0/0/0/0
# 286              Battle Axe         Active       Regular    125/0/0/0/0
#
#     Damage Reduction Aux Effects Stat Requirements Stat Bonuses  Critical  \
# ...

# %% [markdown]
# Код для удаления колонки категории оружия (топоры)

# %%
DS3_weapon.drop_duplicates(subset="Category")
# Out:
#                                  Name            Category Reinforcement  \
# 0                                Fist               Fists       Regular
# 1                   Dragonhead Shield       Small Shields          Boss
# 2              Dragonhead Greatshield        Greatshields          Boss
# 3                     White Birch Bow                Bows        Unique
# 4                Preacher's Right Arm              Staves        Unique
# 5           Sacred Chime of Filianore              Chimes        Unique
# 6                 Ringed Knight Spear               Pikes        Unique
# 7                 Ledo's Great Hammer       Great Hammers        Unique
# 8            Crucifix of the Mad King            Halberds        Unique
# 11                 Repeating Crossbow           Crossbows          Boss
# 12                  Gael's Greatsword         Greatswords          Boss
# 13                       Frayed Blade             Katanas          Boss
# ...

# %% [markdown]
# Код для удаления всех дубликатов в колонке категорий

# %%
DS3_weapon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               287 non-null    object
#  1   Category           287 non-null    object
#  2   Reinforcement      287 non-null    object
#  3   Damage             287 non-null    object
#  4   Damage Reduction   287 non-null    object
#  5   Aux Effects        287 non-null    object
#  6   Stat Requirements  287 non-null    object
#  7   Stat Bonuses       287 non-null    object
#  8   Critical           287 non-null    int64
#  9   Weight             287 non-null    float64
#  10  Stability          287 non-null    object
#  11  Durability         287 non-null    int64
#  12  Sell Price         286 non-null    float64
#  13  Spell Buff         33 non-null     float64
#  14  Range              17 non-null     float64
#  15  Buffable           287 non-null    object
# ...

# %% [markdown]
# Код для анализа датасета с помощью функции info.

# %%
DS3_weapon.describe()
# Out:
#          Critical      Weight  Durability   Sell Price  Spell Buff      Range
# count  287.000000  287.000000  287.000000   286.000000   33.000000  17.000000
# mean   100.923345    6.695122   81.602787   383.513986  216.878788  48.529412
# std      4.023668    5.795789   50.884234   394.900527   45.103186   7.851096
# min    100.000000    0.000000    0.000000     0.000000   60.000000  35.000000
# 25%    100.000000    2.500000   55.000000   100.000000  203.000000  42.000000
# 50%    100.000000    5.000000   70.000000   200.000000  220.000000  50.000000
# 75%    100.000000    9.000000   90.000000   500.000000  232.000000  50.000000
# max    130.000000   28.000000  500.000000  2000.000000  312.000000  63.000000

# %% [markdown]
# Код для анализа датасета с помощью функции describe.

# %%
DS3_weapon.loc[[1,150,200], ["Name", "Category", "Damage"]]
# Out:
#                      Name       Category        Damage
# 1       Dragonhead Shield  Small Shields  116/0/12/0/0
# 150               Warpick        Hammers   113/0/0/0/0
# 200  Vordt's Great Hammer  Great Hammers   176/0/0/0/0

# %% [markdown]
# Код для выборки данных по строкам и столбцам с помощью loc.

# %%
DS3_weapon.to_csv("NewDS3_weapon.csv")

# %% [markdown]
# Код для сохранения нового датасета в csv. Вывод: были показаны на практике полученные на парах навыки работы с numpy и
# pandas.
